# %% [markdown]
# # Extracting results from the template matching search
#
# After running through a template matching process, we have a set of location, correlation, and orientation statistics that need parsed. For example, peaks need to be picked from the z-score map, and the corresponding best orientations and defoci at those locations need to be read.
#
# While the necessary information *can* be grabbed from a configuration file, having a tabular data format is more flexible to work with.

# %%
from leopard_em.pydantic_models.managers import MatchTemplateManager

# %% [markdown]
# ### Importing a configuration
#
# Here, we use an example configuration file to demonstrate how to extract the relevant information.
# If you've already run template matching, then this information should already be present in the `MatchTemplateManager` instance.

# %%
yaml_path = "/some/path/to/your/yaml_file.yaml"
mt_manager = MatchTemplateManager.from_yaml(yaml_path)
mt_result = mt_manager.match_template_result
mt_result.load_tensors_from_paths()  # Needed to load results into memory


# Manually set the number of correlations. Automatically calculated after a run
total_corr = int(13 * 1.59e6)
mt_result.total_projections = total_corr

# %% [markdown]
# ## Extracting minimal peak information
#
# Minimal information at the peaks (location, orientation, peak height) can be extracted from the `MatchTemplateResult` instance as either a `dict` or `pandas.DataFrame`. Here, we show how to extract the information as a `pandas.DataFrame`.

# %%
mt_result.locate_peaks()
df_peaks = mt_result.peaks_to_dataframe()
df_peaks
# Out:
#      pos_x  pos_y          mip  scaled_mip         psi  theta         phi  \
# 0     2629   1416  181684640.0   10.893500  142.500000  137.5    3.711340
# 1     2628   2430  177371376.0   10.462113   51.000000   60.0  -66.239990
# 2     3597   1539  175787392.0   10.374412    4.500000  135.0   84.705887
# 3     3227    721  183324096.0   10.359616   78.000000  155.0  112.131149
# 4     4065   2045  171877360.0   10.332990   27.000000   35.0    0.000000
# ..     ...    ...          ...         ...         ...    ...         ...
# 246    927   2931  132408072.0    7.823109  157.500000   85.0  173.706299
# 247   3422    917  135465952.0    7.822277  -10.499990  135.0  123.529419
# 248    670   1816  122870240.0    7.820220   58.500000  137.5  163.298981
# 249   2432    493  141263456.0    7.815361  -94.499992   82.5   12.587413
# 250   2650   1166  137042048.0    7.815328 -145.500000   87.5  100.000000
#
#      defocus  corr_average  corr_variance  corr_total
# 0     -600.0 -7.203677e+08   3.435034e+14    20670000
# 1    -1200.0  3.823860e+07   3.543295e+14    20670000
# 2     -600.0  1.571909e+09   3.528354e+14    20670000
# 3     -200.0  7.485558e+09   3.825624e+14    20670000
# 4      400.0  5.968749e+09   3.381624e+14    20670000
# ..       ...           ...            ...         ...
# 246   -800.0  6.020112e+09   3.485931e+14    20670000
# 247   -800.0  1.280594e+10   3.639661e+14    20670000
# 248  -1000.0 -2.290174e+10   3.525876e+14    20670000
# 249   -800.0  8.250029e+09   3.968169e+14    20670000
# 250   -200.0  2.258413e+10   3.793992e+14    20670000
#
# [251 rows x 11 columns]

# %% [markdown]
# ## Converting full result information to a DataFrame
#
# The `MatchTemplateManager` class also has a method -- `results_to_dataframe` -- which populates a `pandas.DataFrame` with all necessary information for (most) downstream processing.

# %%
df_full = mt_manager.results_to_dataframe()
df_full
# Out:
#      pos_x  pos_y          mip  scaled_mip         psi  theta         phi  \
# 0     2629   1416  181684640.0   10.893500  142.500000  137.5    3.711340
# 1     2628   2430  177371376.0   10.462113   51.000000   60.0  -66.239990
# 2     3597   1539  175787392.0   10.374412    4.500000  135.0   84.705887
# 3     3227    721  183324096.0   10.359616   78.000000  155.0  112.131149
# 4     4065   2045  171877360.0   10.332990   27.000000   35.0    0.000000
# ..     ...    ...          ...         ...         ...    ...         ...
# 246    927   2931  132408072.0    7.823109  157.500000   85.0  173.706299
# 247   3422    917  135465952.0    7.822277  -10.499990  135.0  123.529419
# 248    670   1816  122870240.0    7.820220   58.500000  137.5  163.298981
# 249   2432    493  141263456.0    7.815361  -94.499992   82.5   12.587413
# 250   2650   1166  137042048.0    7.815328 -145.500000   87.5  100.000000
#
#      defocus  corr_average  corr_variance  ...  \
# 0     -600.0 -7.203677e+08   3.435034e+14  ...
# 1    -1200.0  3.823860e+07   3.543295e+14  ...
# 2     -600.0  1.571909e+09   3.528354e+14  ...
# 3     -200.0  7.485558e+09   3.825624e+14  ...
# 4      400.0  5.968749e+09   3.381624e+14  ...
# ..       ...           ...            ...  ...
# 246   -800.0  6.020112e+09   3.485931e+14  ...
# 247   -800.0  1.280594e+10   3.639661e+14  ...
# 248  -1000.0 -2.290174e+10   3.525876e+14  ...
# 249   -800.0  8.250029e+09   3.968169e+14  ...
# 250   -200.0  2.258413e+10   3.793992e+14  ...
#
#                                               phi_path  \
# 0    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 1    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 2    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 3    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 4    /home/mgiammar/git_repositories/tt2DTM/large_i...
# ..                                                 ...
# 246  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 247  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 248  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 249  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 250  /home/mgiammar/git_repositories/tt2DTM/large_i...
#
#                                           defocus_path  \
# 0    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 1    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 2    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 3    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 4    /home/mgiammar/git_repositories/tt2DTM/large_i...
# ..                                                 ...
# 246  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 247  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 248  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 249  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 250  /home/mgiammar/git_repositories/tt2DTM/large_i...
#
#                               correlation_average_path  \
# 0    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 1    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 2    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 3    /home/mgiammar/git_repositories/tt2DTM/large_i...
# 4    /home/mgiammar/git_repositories/tt2DTM/large_i...
# ..                                                 ...
# 246  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 247  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 248  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 249  /home/mgiammar/git_repositories/tt2DTM/large_i...
# 250  /home/mgiammar/git_repositories/tt2DTM/large_i...
#
#                              correlation_variance_path  pixel_size  voltage  \
# 0    /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 1    /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 2    /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 3    /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 4    /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# ..                                                 ...         ...      ...
# 246  /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 247  /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 248  /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 249  /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
# 250  /home/mgiammar/git_repositories/tt2DTM/large_i...        0.95    300.0
#
#      spherical_aberration  amplitude_contrast_ratio phase_shift ctf_B_factor
# 0                     2.7                      0.07         0.0         60.0
# 1                     2.7                      0.07         0.0         60.0
# 2                     2.7                      0.07         0.0         60.0
# 3                     2.7                      0.07         0.0         60.0
# 4                     2.7                      0.07         0.0         60.0
# ..                    ...                       ...         ...          ...
# 246                   2.7                      0.07         0.0         60.0
# 247                   2.7                      0.07         0.0         60.0
# 248                   2.7                      0.07         0.0         60.0
# 249                   2.7                      0.07         0.0         60.0
# 250                   2.7                      0.07         0.0         60.0
#
# [251 rows x 34 columns]
